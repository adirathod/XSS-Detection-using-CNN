# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Second_Sem Projects/Database Security Project/Dataset/XSS_dataset.csv', encoding='utf-8-sig')
df.head()
# Out:
#    Unnamed: 0                                           Sentence  Label
# 0           0  <li><a href="/wiki/File:Socrates.png" class="i...      0
# 1           1               <tt onmouseover="alert(1)">test</tt>      1
# 2           2  \t </span> <span class="reference-text">Steeri...      0
# 3           3  \t </span> <span class="reference-text"><cite ...      0
# 4           4  \t </span>. <a href="/wiki/Digital_object_iden...      0

# %%
def data2char_index(X, max_len):
    alphabet = " abcdefghijklmnopqrstuvwxyz0123456789-,;.!?:'\"/\\|_@#$%^&*~`+-=<>()[]{}"
    result = [] 
    for data in X:
        mat = []
        for ch in data:
            if ch not in alphabet:
                continue
            mat.append(alphabet.index(ch))
        result.append(mat)   
    X_char = tf.keras.preprocessing.sequence.pad_sequences(np.array(result, dtype=object), padding='post',
                                                           truncating='post', maxlen=max_len)
    return X_char

# %%
data = df['Sentence'].values
label = df['Label'].values

trainX, testX, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)

x_train = data2char_index(trainX, max_len=1000)
x_test = data2char_index(testX, max_len=1000)

# %%
x_train.shape
# Out:
# (10948, 1000)

# %%
x_test.shape
# Out:
# (2738, 1000)

# %%
def get_charcnn_model(max_len):
    main_input = tf.keras.layers.Input(shape=(max_len,))
    
    embedder = tf.keras.layers.Embedding(
        input_dim=70,  
        output_dim=80, 
        input_length=max_len,
        trainable=False
    )
    embed = embedder(main_input)
    
    cnn1 = tf.keras.layers.Conv1D(32, 5, padding='same', strides=1, activation='relu')(embed)
    cnn1 = tf.keras.layers.MaxPooling1D(pool_size=12)(cnn1)
    
    cnn2 = tf.keras.layers.Conv1D(32, 10, padding='same', strides=1, activation='relu')(embed)
    cnn2 = tf.keras.layers.MaxPooling1D(pool_size=11)(cnn2)
    
    cnn3 = tf.keras.layers.Conv1D(32, 15, padding='same', strides=1, activation='relu')(embed)
    cnn3 = tf.keras.layers.MaxPooling1D(pool_size=10)(cnn3)
    
    cnn = tf.keras.layers.concatenate([cnn1, cnn2, cnn3], axis=1)
    flat = tf.keras.layers.Flatten()(cnn)
    drop = tf.keras.layers.Dropout(0.2)(flat)
    dense1 = tf.keras.layers.Dense(1024, activation='relu')(drop)
    dense2 = tf.keras.layers.Dense(128, activation='relu')(dense1)
    main_output = tf.keras.layers.Dense(1, activation='sigmoid')(dense2)
    model = tf.keras.Model(inputs=main_input, outputs=main_output)
    return model

# %%
model = get_charcnn_model(max_len=1000)
model.compile(
    loss='binary_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1000)]       0           []
#
#  embedding (Embedding)          (None, 1000, 80)     5600        ['input_1[0][0]']
#
#  conv1d (Conv1D)                (None, 1000, 32)     12832       ['embedding[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 1000, 32)     25632       ['embedding[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1000, 32)     38432       ['embedding[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 83, 32)       0           ['conv1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 90, 32)      0           ['conv1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 100, 32)     0           ['conv1d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 273, 32)      0           ['max_pooling1d[0][0]',
#                                                                   'max_pooling1d_1[0][0]',
#                                                                   'max_pooling1d_2[0][0]']
#
#  flatten (Flatten)              (None, 8736)         0           ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 8736)         0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 1024)         8946688     ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 128)          131200      ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 1)            129         ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 9,160,513
# Trainable params: 9,154,913
# Non-trainable params: 5,600
# __________________________________________________________________________________________________

# %%
batch_size = 128
num_epoch = 15
model_log = model.fit(
    x_train, 
    y_train,
    batch_size=batch_size,
    epochs=num_epoch,
    verbose=1,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/15
# 86/86 [==============================] - 170s 2s/step - loss: 0.1450 - accuracy: 0.9308 - val_loss: 0.0196 - val_accuracy: 0.9934
# Epoch 2/15
# 86/86 [==============================] - 168s 2s/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.0090 - val_accuracy: 0.9967
# Epoch 3/15
# 86/86 [==============================] - 167s 2s/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0047 - val_accuracy: 0.9978
# Epoch 4/15
# 86/86 [==============================] - 167s 2s/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0045 - val_accuracy: 0.9982
# Epoch 5/15
# 86/86 [==============================] - 168s 2s/step - loss: 7.1068e-04 - accuracy: 0.9998 - val_loss: 0.0062 - val_accuracy: 0.9982
# Epoch 6/15
# 86/86 [==============================] - 167s 2s/step - loss: 8.5194e-04 - accuracy: 0.9995 - val_loss: 0.0057 - val_accuracy: 0.9974
# Epoch 7/15
# 86/86 [==============================] - 167s 2s/step - loss: 2.3233e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 0.9993
# Epoch 8/15
# 86/86 [==============================] - 167s 2s/step - loss: 2.5842e-04 - accuracy: 0.9999 - val_loss: 0.0033 - val_accuracy: 0.9985
# Epoch 9/15
# 86/86 [==============================] - 167s 2s/step - loss: 1.1298e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9993
# Epoch 10/15
# 86/86 [==============================] - 167s 2s/step - loss: 3.8630e-05 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9993
# Epoch 11/15
# 86/86 [==============================] - 167s 2s/step - loss: 5.3737e-05 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9993
# Epoch 12/15
# 86/86 [==============================] - 167s 2s/step - loss: 1.4450e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9989
# Epoch 13/15
# 86/86 [==============================] - 167s 2s/step - loss: 2.6204e-05 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9985
# Epoch 14/15
# 86/86 [==============================] - 168s 2s/step - loss: 1.3072e-05 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9993
# Epoch 15/15
# 86/86 [==============================] - 168s 2s/step - loss: 1.2088e-05 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 0.9993

# %%
pred = model.predict(x_test)
y_pred = np.int64(pred>0.5)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print(" Accuracy : {0} \n Precision : {1} \n Recall : {2}".format(accuracy, precision, recall))
# Out:
#  Accuracy : 0.9992695398100804
#  Precision : 1.0
#  Recall : 0.9986468200270636
